# %%
size = rows* columns 
isnull / isna ==  it use to find all the null values boolean 
isnull().sum()/isna().sum() == it gives us the sum of null value
fillna = it is used to fill the null values
dropna = to drop the null values /axis = 0 == rows  , axis =  1 column

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## sort_index:- it is used to sort the index in acsending order
#
# sort_index(axis = 0)   === for sorting according to the rows
# sort_index(axis = 1)   === for sorting according to the column
#
# syntax -- df.sort_index(axis=0)
#           df.sort_index(axis=1)
#
# Parameters =
# axis =0
# axis  =1
# ascending = False  (it is use to sort data in Desceding Order)
# by default it is True  (bydefault it sort data in Asceding order)

# %%
df2 = pd.read_csv('Emp_Records  (1).csv')
df2
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df1 = df.sort_index(axis=0) 
df1
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df2 = df.sort_index(axis = 1)
df2
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36           NaN  677509       Lois  168251
# 1              NaN       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0             NaN
# 1             NaN
# 2            68.0
# 3             NaN
# 4            58.0
# ..            ...
# 95           89.0
# 96           77.0
# 97           60.0
# 98           57.0
# 99           55.0
#
# [100 rows x 7 columns]

# %%
df2
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36           NaN  677509       Lois  168251
# 1              NaN       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0             NaN
# 1             NaN
# 2            68.0
# 3             NaN
# 4            58.0
# ..            ...
# 95           89.0
# 96           77.0
# 97           60.0
# 98           57.0
# 99           55.0
#
# [100 rows x 7 columns]

# %%
df.sort_index(axis = 1,inplace = True)
df
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36           NaN  677509       Lois  168251
# 1              NaN       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0             NaN
# 1             NaN
# 2            68.0
# 3             NaN
# 4            58.0
# ..            ...
# 95           89.0
# 96           77.0
# 97           60.0
# 98           57.0
# 99           55.0
#
# [100 rows x 7 columns]

# %%
df
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36           NaN  677509       Lois  168251
# 1              NaN       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0             NaN
# 1             NaN
# 2            68.0
# 3             NaN
# 4            58.0
# ..            ...
# 95           89.0
# 96           77.0
# 97           60.0
# 98           57.0
# 99           55.0
#
# [100 rows x 7 columns]

# %% [markdown]
# # df.T == it chnages rows to columns and columns to the rows
#
# syntax:- df.T
# (df.T).sort_index(axis=0)
#
# parameters
# axis =0  rows
# axis = 1 columns

# %%
df1.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
#
#         City
# 0        NaN
# 1  Stonewall

# %%
df1.T
# Out:
#                     0          1             2         3         4   \
# Emp ID          677509     940761        428945    408351    193819
# First Name        Lois     Brenda           Joe     Diane  Benjamin
# Age in Yrs       36.36      47.02         54.15     39.67     40.31
# Weight in Kgs      NaN        NaN          68.0       NaN      58.0
# Age in Company   13.68        NaN          0.98      18.3      4.01
# Salary          168251      51063         50155    180294    117642
# City               NaN  Stonewall  Michigantown  Hydetown   Fremont
#
#                        5        6            7        8               9   ...  \
# Emp ID             499687   539712       380086   477616          162402  ...
# First Name        Patrick    Nancy        Carol  Frances           Diana  ...
# Age in Yrs          34.86    22.14        59.12    58.18           29.73  ...
# Weight in Kgs        58.0     50.0         40.0     42.0            60.0  ...
# Age in Company      12.02     0.87        34.52    23.27            3.44  ...
# Salary              72305    98189        60918   121587           43010  ...
# City            Macksburg  Atlanta  Blanchester  Delmita  Eureka Springs  ...
#
#                     90       91                       92            93  \
# Emp ID          185032   867084                   969964        158666
# First Name      Eugene  Deborah                   Janice       Rebecca
# Age in Yrs       37.84    39.77                    37.57          56.0
# Weight in Kgs     59.0     54.0                     56.0          55.0
# Age in Company    2.64    15.41                     0.93         34.32
# Salary          122950    52767                   147641        160043
# City            Racine  Atqasuk  Whiteman Air Force Base  Independence
#
#                       94      95            96       97        98      99
# Emp ID            489424  639892        704709   461593    392491  495141
# First Name       Phillip    Jose        Harold   Nicole   Theresa   Tammy
# Age in Yrs         39.43   22.82         32.61    52.66      29.6   38.38
# Weight in Kgs       82.0    89.0          77.0     60.0      57.0    55.0
# Age in Company      1.56    1.05          5.93    28.53      6.99    2.26
# Salary            181774  129774        156194    95673     51015   93650
# City            Mapleton  Biloxi  Carol Stream  Detroit  Mc Grath    Alma
#
# [7 rows x 100 columns]

# %%
(df1.T).sort_index(axis=0)
# Out:
#                     0          1             2         3         4   \
# Age in Company   13.68        NaN          0.98      18.3      4.01
# Age in Yrs       36.36      47.02         54.15     39.67     40.31
# City               NaN  Stonewall  Michigantown  Hydetown   Fremont
# Emp ID          677509     940761        428945    408351    193819
# First Name        Lois     Brenda           Joe     Diane  Benjamin
# Salary          168251      51063         50155    180294    117642
# Weight in Kgs      NaN        NaN          68.0       NaN      58.0
#
#                        5        6            7        8               9   ...  \
# Age in Company      12.02     0.87        34.52    23.27            3.44  ...
# Age in Yrs          34.86    22.14        59.12    58.18           29.73  ...
# City            Macksburg  Atlanta  Blanchester  Delmita  Eureka Springs  ...
# Emp ID             499687   539712       380086   477616          162402  ...
# First Name        Patrick    Nancy        Carol  Frances           Diana  ...
# Salary              72305    98189        60918   121587           43010  ...
# Weight in Kgs        58.0     50.0         40.0     42.0            60.0  ...
#
#                     90       91                       92            93  \
# Age in Company    2.64    15.41                     0.93         34.32
# Age in Yrs       37.84    39.77                    37.57          56.0
# City            Racine  Atqasuk  Whiteman Air Force Base  Independence
# Emp ID          185032   867084                   969964        158666
# First Name      Eugene  Deborah                   Janice       Rebecca
# Salary          122950    52767                   147641        160043
# Weight in Kgs     59.0     54.0                     56.0          55.0
#
#                       94      95            96       97        98      99
# Age in Company      1.56    1.05          5.93    28.53      6.99    2.26
# Age in Yrs         39.43   22.82         32.61    52.66      29.6   38.38
# City            Mapleton  Biloxi  Carol Stream  Detroit  Mc Grath    Alma
# Emp ID            489424  639892        704709   461593    392491  495141
# First Name       Phillip    Jose        Harold   Nicole   Theresa   Tammy
# Salary            181774  129774        156194    95673     51015   93650
# Weight in Kgs       82.0    89.0          77.0     60.0      57.0    55.0
#
# [7 rows x 100 columns]

# %% [markdown]
# ## set_index
#
# it is used to replaced the index
# syntax:- df1 = df.set_index('Column Name')    #for replacing the index
#          df1
#          df1.sort_index(axis=0)
#
# Parameters
# axis =0
# axis =1

# %%
df1.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
#
#         City
# 0        NaN
# 1  Stonewall

# %%
df3 = df1.set_index("Age in Yrs")
# Out:
#             Emp ID First Name  Weight in Kgs  Age in Company  Salary  \
# Age in Yrs
# 36.36       677509       Lois            NaN           13.68  168251
# 47.02       940761     Brenda            NaN             NaN   51063
# 54.15       428945        Joe           68.0            0.98   50155
# 39.67       408351      Diane            NaN           18.30  180294
# 40.31       193819   Benjamin           58.0            4.01  117642
# ...            ...        ...            ...             ...     ...
# 22.82       639892       Jose           89.0            1.05  129774
# 32.61       704709     Harold           77.0            5.93  156194
# 52.66       461593     Nicole           60.0           28.53   95673
# 29.60       392491    Theresa           57.0            6.99   51015
# 38.38       495141      Tammy           55.0            2.26   93650
#
#                     City
# Age in Yrs
# 36.36                NaN
# 47.02          Stonewall
# 54.15       Michigantown
# 39.67           Hydetown
# 40.31            Fremont
# ...                  ...
# 22.82             Biloxi
# 32.61       Carol Stream
# 52.66            Detroit
# 29.60           Mc Grath
# 38.38               Alma
#
# [100 rows x 6 columns]

# %%
df3.sort_index(axis = 0)
# Out:
#             Emp ID First Name  Weight in Kgs  Age in Company  Salary  \
# Age in Yrs
# 21.10       301576      Wayne           87.0            0.02   92758
# 21.30       879753     Pamela           47.0            0.13  149262
# 21.93       750173    Antonio           82.0            0.24  181646
# 22.14       539712      Nancy           50.0            0.87   98189
# 22.21       153989       Jack           61.0            0.56   82965
# ...            ...        ...            ...             ...     ...
# 58.43       528673       Paul           60.0           22.10  145235
# 59.12       380086      Carol           40.0           34.52   60918
# 59.27       515103       Anne           48.0           14.01  114426
# 59.42       560455    Carolyn           53.0           16.08   42005
# 59.47       441771     Cheryl           47.0           26.69   92220
#
#                    City
# Age in Yrs
# 21.10             Maida
# 21.30            Banner
# 21.93          Mc Calla
# 22.14           Atlanta
# 22.21         Las Vegas
# ...                 ...
# 58.43        Blue River
# 59.12       Blanchester
# 59.27        Cookeville
# 59.42       Saint Cloud
# 59.47          Quecreek
#
# [100 rows x 6 columns]

# %%
df2=df1.set_index("First Name")
df2
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36            NaN           13.68  168251
# Brenda      940761       47.02            NaN             NaN   51063
# Joe         428945       54.15           68.0            0.98   50155
# Diane       408351       39.67            NaN           18.30  180294
# Benjamin    193819       40.31           58.0            4.01  117642
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82           89.0            1.05  129774
# Harold      704709       32.61           77.0            5.93  156194
# Nicole      461593       52.66           60.0           28.53   95673
# Theresa     392491       29.60           57.0            6.99   51015
# Tammy       495141       38.38           55.0            2.26   93650
#
#                     City
# First Name
# Lois                 NaN
# Brenda         Stonewall
# Joe         Michigantown
# Diane           Hydetown
# Benjamin         Fremont
# ...                  ...
# Jose              Biloxi
# Harold      Carol Stream
# Nicole           Detroit
# Theresa         Mc Grath
# Tammy               Alma
#
# [100 rows x 6 columns]

# %%
df2.head(2)
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36            NaN           13.68  168251
# Brenda      940761       47.02            NaN             NaN   51063
#
#                  City
# First Name
# Lois              NaN
# Brenda      Stonewall

# %%
df2.sort_index(axis=0)
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Aaron       218791       48.49           56.0           20.08   54402
# Alan        247137       38.65           80.0           11.15  154810
# Amanda      227922       35.02           40.0           10.28  114257
# Amy         893212       36.14           52.0           14.17  112715
# Andrea      183071       32.08           52.0            7.28   54179
# ...            ...         ...            ...             ...     ...
# Theresa     214352       24.66           59.0            2.52  197537
# Thomas      622406       49.85           73.0           19.15   73862
# Todd        917937       25.93           74.0            1.22  163560
# Wayne       301576       21.10           87.0            0.02   92758
# William     806955       50.05           50.0           17.36   73734
#
#                     City
# First Name
# Aaron            Eckerty
# Alan           Knoxville
# Amanda      Lake Charles
# Amy                Kline
# Andrea           Granger
# ...                  ...
# Theresa      Toeterville
# Thomas         Dutchtown
# Todd        Randallstown
# Wayne              Maida
# William      Mary Esther
#
# [100 rows x 6 columns]

# %% [markdown]
# ### ascending = True by default and if we put the  ascending=False then it sort in decending order
#
# df1.sort_index(axis=0, ascending=False,inplace=True)
# df1

# %%
df1.sort_index(axis=0, ascending=False,inplace=True)
df1
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 99  495141      Tammy       38.38           55.0            2.26   93650
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 96  704709     Harold       32.61           77.0            5.93  156194
# 95  639892       Jose       22.82           89.0            1.05  129774
# ..     ...        ...         ...            ...             ...     ...
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 3   408351      Diane       39.67            NaN           18.30  180294
# 2   428945        Joe       54.15           68.0            0.98   50155
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 0   677509       Lois       36.36            NaN           13.68  168251
#
#             City
# 99          Alma
# 98      Mc Grath
# 97       Detroit
# 96  Carol Stream
# 95        Biloxi
# ..           ...
# 4        Fremont
# 3       Hydetown
# 2   Michigantown
# 1      Stonewall
# 0            NaN
#
# [100 rows x 7 columns]

# %%
df3=df1.set_index("First Name")
df3
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Tammy       495141       38.38           55.0            2.26   93650
# Theresa     392491       29.60           57.0            6.99   51015
# Nicole      461593       52.66           60.0           28.53   95673
# Harold      704709       32.61           77.0            5.93  156194
# Jose        639892       22.82           89.0            1.05  129774
# ...            ...         ...            ...             ...     ...
# Benjamin    193819       40.31           58.0            4.01  117642
# Diane       408351       39.67            NaN           18.30  180294
# Joe         428945       54.15           68.0            0.98   50155
# Brenda      940761       47.02            NaN             NaN   51063
# Lois        677509       36.36            NaN           13.68  168251
#
#                     City
# First Name
# Tammy               Alma
# Theresa         Mc Grath
# Nicole           Detroit
# Harold      Carol Stream
# Jose              Biloxi
# ...                  ...
# Benjamin         Fremont
# Diane           Hydetown
# Joe         Michigantown
# Brenda         Stonewall
# Lois                 NaN
#
# [100 rows x 6 columns]

# %%
df3.sort_index(axis=0, ascending=False,inplace=True)
df3
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# William     806955       50.05           50.0           17.36   73734
# Wayne       301576       21.10           87.0            0.02   92758
# Todd        917937       25.93           74.0            1.22  163560
# Thomas      622406       49.85           73.0           19.15   73862
# Theresa     214352       24.66           59.0            2.52  197537
# ...            ...         ...            ...             ...     ...
# Andrea      183071       32.08           52.0            7.28   54179
# Amy         893212       36.14           52.0           14.17  112715
# Amanda      227922       35.02           40.0           10.28  114257
# Alan        247137       38.65           80.0           11.15  154810
# Aaron       218791       48.49           56.0           20.08   54402
#
#                     City
# First Name
# William      Mary Esther
# Wayne              Maida
# Todd        Randallstown
# Thomas         Dutchtown
# Theresa      Toeterville
# ...                  ...
# Andrea           Granger
# Amy                Kline
# Amanda      Lake Charles
# Alan           Knoxville
# Aaron            Eckerty
#
# [100 rows x 6 columns]

# %% [markdown]
# ## reset_index
# df1.reset_index()
# df1.reset_index(inplace=True)

# %%
df2.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
#
#         City
# 0        NaN
# 1  Stonewall

# %%
df3 = df2.set_index("First Name")
df3
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36            NaN           13.68  168251
# Brenda      940761       47.02            NaN             NaN   51063
# Joe         428945       54.15           68.0            0.98   50155
# Diane       408351       39.67            NaN           18.30  180294
# Benjamin    193819       40.31           58.0            4.01  117642
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82           89.0            1.05  129774
# Harold      704709       32.61           77.0            5.93  156194
# Nicole      461593       52.66           60.0           28.53   95673
# Theresa     392491       29.60           57.0            6.99   51015
# Tammy       495141       38.38           55.0            2.26   93650
#
#                     City
# First Name
# Lois                 NaN
# Brenda         Stonewall
# Joe         Michigantown
# Diane           Hydetown
# Benjamin         Fremont
# ...                  ...
# Jose              Biloxi
# Harold      Carol Stream
# Nicole           Detroit
# Theresa         Mc Grath
# Tammy               Alma
#
# [100 rows x 6 columns]

# %%
df2.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
#
#         City
# 0        NaN
# 1  Stonewall

# %%
df3.reset_index(inplace=True)
df3
# Out:
#     index First Name  Emp ID  Age in Yrs  Weight in Kgs  Age in Company  \
# 0       0       Lois  677509       36.36            NaN           13.68
# 1       1     Brenda  940761       47.02            NaN             NaN
# 2       2        Joe  428945       54.15           68.0            0.98
# 3       3      Diane  408351       39.67            NaN           18.30
# 4       4   Benjamin  193819       40.31           58.0            4.01
# ..    ...        ...     ...         ...            ...             ...
# 95     95       Jose  639892       22.82           89.0            1.05
# 96     96     Harold  704709       32.61           77.0            5.93
# 97     97     Nicole  461593       52.66           60.0           28.53
# 98     98    Theresa  392491       29.60           57.0            6.99
# 99     99      Tammy  495141       38.38           55.0            2.26
#
#     Salary          City
# 0   168251           NaN
# 1    51063     Stonewall
# 2    50155  Michigantown
# 3   180294      Hydetown
# 4   117642       Fremont
# ..     ...           ...
# 95  129774        Biloxi
# 96  156194  Carol Stream
# 97   95673       Detroit
# 98   51015      Mc Grath
# 99   93650          Alma
#
# [100 rows x 8 columns]

# %%
df3
# Out:
#    First Name  Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0        Lois  677509       36.36            NaN           13.68  168251
# 1      Brenda  940761       47.02            NaN             NaN   51063
# 2         Joe  428945       54.15           68.0            0.98   50155
# 3       Diane  408351       39.67            NaN           18.30  180294
# 4    Benjamin  193819       40.31           58.0            4.01  117642
# ..        ...     ...         ...            ...             ...     ...
# 95       Jose  639892       22.82           89.0            1.05  129774
# 96     Harold  704709       32.61           77.0            5.93  156194
# 97     Nicole  461593       52.66           60.0           28.53   95673
# 98    Theresa  392491       29.60           57.0            6.99   51015
# 99      Tammy  495141       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %% [markdown]
# ## sort_values
# df.sort_values('First Name')
# df.sort_values('Age in Yrs')
# df.sort_values('Age in Yrs', ascending=False)

# %%
df2.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
#
#         City
# 0        NaN
# 1  Stonewall

# %%
df2.sort_values('Age in Yrs')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 49  879753     Pamela       21.30           47.0            0.13  149262
# 59  750173    Antonio       21.93           82.0            0.24  181646
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 11  153989       Jack       22.21           61.0            0.56   82965
# ..     ...        ...         ...            ...             ...     ...
# 74  528673       Paul       58.43           60.0           22.10  145235
# 7   380086      Carol       59.12           40.0           34.52   60918
# 57  515103       Anne       59.27           48.0           14.01  114426
# 24  560455    Carolyn       59.42           53.0           16.08   42005
# 14  441771     Cheryl       59.47           47.0           26.69   92220
#
#            City
# 13        Maida
# 49       Banner
# 59     Mc Calla
# 6       Atlanta
# 11    Las Vegas
# ..          ...
# 74   Blue River
# 7   Blanchester
# 57   Cookeville
# 24  Saint Cloud
# 14     Quecreek
#
# [100 rows x 7 columns]

# %%
df2.sort_values('Age in Yrs',ascending=False) 
#ascending=False  To sort data in decending order
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 14  441771     Cheryl       59.47           47.0           26.69   92220
# 24  560455    Carolyn       59.42           53.0           16.08   42005
# 57  515103       Anne       59.27           48.0           14.01  114426
# 7   380086      Carol       59.12           40.0           34.52   60918
# 74  528673       Paul       58.43           60.0           22.10  145235
# ..     ...        ...         ...            ...             ...     ...
# 11  153989       Jack       22.21           61.0            0.56   82965
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 59  750173    Antonio       21.93           82.0            0.24  181646
# 49  879753     Pamela       21.30           47.0            0.13  149262
# 13  301576      Wayne       21.10           87.0            0.02   92758
#
#            City
# 14     Quecreek
# 24  Saint Cloud
# 57   Cookeville
# 7   Blanchester
# 74   Blue River
# ..          ...
# 11    Las Vegas
# 6       Atlanta
# 59     Mc Calla
# 49       Banner
# 13        Maida
#
# [100 rows x 7 columns]

# %% [markdown]
# # Drop the feature

# %% [markdown]
# If you want to drop a specific Feature the we use the drop
# df1 = df.drop(["City","Salary"],axis =1)
# df1

# %%
df2.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
#
#         City
# 0        NaN
# 1  Stonewall

# %%
df5 = df2.drop(["First Name"],axis =1)
df5
# Out:
#     Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary          City
# 0   677509       36.36            NaN           13.68  168251           NaN
# 1   940761       47.02            NaN             NaN   51063     Stonewall
# 2   428945       54.15           68.0            0.98   50155  Michigantown
# 3   408351       39.67            NaN           18.30  180294      Hydetown
# 4   193819       40.31           58.0            4.01  117642       Fremont
# ..     ...         ...            ...             ...     ...           ...
# 95  639892       22.82           89.0            1.05  129774        Biloxi
# 96  704709       32.61           77.0            5.93  156194  Carol Stream
# 97  461593       52.66           60.0           28.53   95673       Detroit
# 98  392491       29.60           57.0            6.99   51015      Mc Grath
# 99  495141       38.38           55.0            2.26   93650          Alma
#
# [100 rows x 6 columns]

# %%
df6 = df2.drop(["First Name","City"],axis = 1)
df6
# Out:
#     Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary
# 0   677509       36.36            NaN           13.68  168251
# 1   940761       47.02            NaN             NaN   51063
# 2   428945       54.15           68.0            0.98   50155
# 3   408351       39.67            NaN           18.30  180294
# 4   193819       40.31           58.0            4.01  117642
# ..     ...         ...            ...             ...     ...
# 95  639892       22.82           89.0            1.05  129774
# 96  704709       32.61           77.0            5.93  156194
# 97  461593       52.66           60.0           28.53   95673
# 98  392491       29.60           57.0            6.99   51015
# 99  495141       38.38           55.0            2.26   93650
#
# [100 rows x 5 columns]

# %% [markdown]
# # value_counts() = it gives the count of all the differnt values in the column.
# df['City'].value_counts()

# %%
df2.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351      Diane       39.67            NaN           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
#
#            City
# 0           NaN
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
df2["City"].value_counts()
# Out:
# City
# Stonewall       1
# Albion          1
# Eckert          1
# Haswell         1
# Kansas City     1
#                ..
# Kline           1
# Panacea         1
# Mesa            1
# Lawrenceburg    1
# Alma            1
# Name: count, Length: 99, dtype: int64

# %%
data = pd.read_csv("Iris .csv")
data.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
data["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # unique() -it gives us the list of unique elements in the feature
# df['City'].unique()

# %%
df2['City'].unique()
# Out:
# array([nan, 'Stonewall', 'Michigantown', 'Hydetown', 'Fremont',
#        'Macksburg', 'Atlanta', 'Blanchester', 'Delmita', 'Eureka Springs',
#        'Sabetha', 'Las Vegas', 'New Matamoras', 'Maida', 'Quecreek',
#        'Beulaville', 'New Douglas', 'Toeterville', 'Primm Springs',
#        'Dutchtown', 'Shreveport', 'Heathsville', 'Middleport', 'Woodbury',
#        'Saint Cloud', 'Stockholm', 'Manning', 'Mount Vernon',
#        'Lawrenceburg', 'Mesa', 'Panacea', 'Kline', 'Bonanza', 'Liberty',
#        'Ohatchee', 'Nashville', 'Eckerty', 'Lima', 'Wright', 'Ellsworth',
#        'Conroy', 'Lake Charles', 'Kalvesta', 'Knoxville', 'Rochester',
#        'Bowling Green', 'Uniontown', 'Topeka', 'New York City', 'Banner',
#        'East Saint Louis', 'Hancock', 'Eatontown', 'Portage', 'Oneida',
#        'Bartley', 'Arlee', 'Cookeville', 'Saxe', 'Mc Calla', 'Trego',
#        'Blair', 'Riverside', 'Maxwell', 'Randallstown', 'Willow Beach',
#        'Granger', 'Alcoa', 'Baton Rouge', 'Browning', 'Hudson',
#        'Kansas City', 'Haswell', 'Eckert', 'Blue River', 'Albion', 'Bays',
#        'Nardin', 'Mary Esther', 'Wheaton', 'Margie', 'Glidden',
#        'Saranac Lake', 'Philadelphia', 'Jarreau', 'Wichita', 'Meno',
#        'Oriskany', 'Richmond Dale', 'Miami', 'Racine', 'Atqasuk',
#        'Whiteman Air Force Base', 'Independence', 'Mapleton', 'Biloxi',
#        'Carol Stream', 'Detroit', 'Mc Grath', 'Alma'], dtype=object)

# %%
data["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
FUNCTIONS:
    
head      = bydefault it gives us first 5 observation (12)
tail      = bydefault it gives us last 5 observation (12)
info      = rageindex :    ,data colume (no.columns),null values and data type,memeory allocation
size      = multiplication of rows and col 
shape     = colu and rows value out put in tuple data type
describe  = it gives us numerical values mean,meadian,sd,max min,25%,75%,50%,
isnull.sum()   = exact count of null value
isnull() = it gives boolean value true for the null value ,false for the regular value
isna    = same as isnull
fillna  = it fills all the null values by anything
columns  = name of cloumns and length of colm
index    =(sart ,stop,step)
axes      =it the combinations index and columns 
loc       =it will the access the rows and columns 
iloc      =it will the access the rows and columns by indexing or we can access the single elemnet from the ilco
sort_index = it sort the index  axis= 0 rows ,axis =1 columns
set_index  = for replacing the index 
reset_index = original indexing 
sort_values = for sorting pericular col/features
df.T       =it convert row to col and col to row
value_counts()  = it gives a count of unique values of the specific Feature
unique()      = it gives us a list of unique values
Drop = it is use to drop a specific Features


PARAMETERS:
inplace =True   == if we want to store the changes in the dataframe 
axis =0 >> Rows
     =1 >> Columns
ascending
