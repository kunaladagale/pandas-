# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\adaga\OneDrive\Desktop\python ETC\pandas\Sarika Maam pandas\Datasets\movies_updated (2).csv")
df.head(4)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4000 non-null   object
#  1   rating     3960 non-null   object
#  2   genre      4000 non-null   object
#  3   year       4000 non-null   int64
#  4   released   4000 non-null   object
#  5   score      4000 non-null   float64
#  6   votes      4000 non-null   int64
#  7   director   4000 non-null   object
#  8   writer     3999 non-null   object
#  9   star       3999 non-null   object
#  10  country    4000 non-null   object
#  11  budget     4000 non-null   int64
#  12  gross      3831 non-null   float64
#  13  company    3990 non-null   object
#  14  runtime,,  4000 non-null   object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 468.9+ KB

# %%
df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 3995  False   False  False  False     False  False  False     False   False
# 3996  False   False  False  False     False  False  False     False   False
# 3997  False   False  False  False     False  False  False     False   False
# 3998  False   False  False  False     False  False  False     False   False
# 3999  False   False  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime,,
# ...

# %%
df.isnull().sum()
# Out:
# name           0
# rating        40
# genre          0
# year           0
# released       0
# score          0
# votes          0
# director       0
# writer         1
# star           1
# country        0
# budget         0
# gross        169
# company       10
# runtime,,      0
# dtype: int64

# %%
df.head(2)
# Out:
#               name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score   votes         director                   writer            star  \
# 0    8.4  927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country    budget       gross            company runtime,,
# 0  United Kingdom  19000000  46998772.0       Warner Bros.    146.0,
# 1   United States   4500000  58853106.0  Columbia Pictures    104.0,

# %% [markdown]
# # Group By
# it is used to make a group of the data according to the conditions

# %%
df['genre'].unique()
# Out:
# array(['Drama', 'Adventure', 'Action', 'Comedy', 'Horror', 'Biography',
#        'Crime', 'Fantasy', 'Family', 'Sci-Fi', 'Animation', 'Romance',
#        'Music', 'Western', 'Thriller', 'History', 'Mystery'], dtype=object)

# %%
len(df['genre'].unique())
# Out:
# 17

# %%
df.groupby('genre') #

# %% [raw]
# ['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy']

# %%
df1 = df.groupby("genre")
df1

# %%
df1= df.groupby(["genre","rating"]).get_group(("Action","PG"))
df1
# Out:
#                                                 name rating   genre  year  \
# 2     Star Wars: Episode V - The Empire Strikes Back     PG  Action  1980
# 8                                        Superman II     PG  Action  1980
# 10                             Any Which Way You Can     PG  Action  1980
# 22                               The Final Countdown     PG  Action  1980
# 27                                 Raise the Titanic     PG  Action  1980
# ...                                              ...    ...     ...   ...
# 3589                       Godzilla 2000: Millennium     PG  Action  1999
# 3891                                        Spy Kids     PG  Action  2001
# 3917                 Crocodile Dundee in Los Angeles     PG  Action  2001
# 3954                                  Shaolin Soccer     PG  Action  2001
# 3969                                     Cats & Dogs     PG  Action  2001
#
#                                released  score    votes           director  \
# ...

# %%
df1 = df.groupby('genre').get_group('Action')
df1
# Out:
#                                                 name rating   genre  year  \
# 2     Star Wars: Episode V - The Empire Strikes Back     PG  Action  1980
# 6                                 The Blues Brothers      R  Action  1980
# 8                                        Superman II     PG  Action  1980
# 10                             Any Which Way You Can     PG  Action  1980
# 22                               The Final Countdown     PG  Action  1980
# ...                                              ...    ...     ...   ...
# 3969                                     Cats & Dogs     PG  Action  2001
# 3972                              Kiss of the Dragon      R  Action  2001
# 3982                                      Formula 51      R  Action  2001
# 3983                                      15 Minutes      R  Action  2001
# 3993                                   The Musketeer  PG-13  Action  2001
#
#                                released  score    votes           director  \
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 3995                                   Birthday Girl      R     Comedy  2001
# 3996                                    Human Nature      R     Comedy  2001
# 3997                                            Made      R     Comedy  2001
# 3998                           One Night at McCool's      R     Comedy  2001
# 3999                                  Dr. Dolittle 2     PG     Comedy  2001
#
# ...

# %%
len(df['name'].unique())
# Out:
# 3971

# %%
df['rating'].unique()
# Out:
# array(['R', 'PG', 'G', nan, 'Not Rated', 'NC-17', 'Approved', 'TV-PG',
#        'PG-13', 'Unrated', 'X', 'TV-MA'], dtype=object)

# %%
df.groupby('rating').get_group('R')
# Out:
#                        name rating      genre  year  \
# 0               The Shining      R      Drama  1980
# 1           The Blue Lagoon      R  Adventure  1980
# 4                Caddyshack      R     Comedy  1980
# 5           Friday the 13th      R     Horror  1980
# 6        The Blues Brothers      R     Action  1980
# ...                     ...    ...        ...   ...
# 3994                      O      R      Drama  2001
# 3995          Birthday Girl      R     Comedy  2001
# 3996           Human Nature      R     Comedy  2001
# 3997                   Made      R     Comedy  2001
# 3998  One Night at McCool's      R     Comedy  2001
#
#                               released  score   votes            director  \
# 0        June 13, 1980 (United States)    8.4  927000     Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8   65000      Randal Kleiser
# 4        July 25, 1980 (United States)    7.3  108000        Harold Ramis
# ...

# %%
df.groupby(['name','genre']).get_group(('Superman II','Action'))
# Out:
#           name rating   genre  year                       released  score  \
# 8  Superman II     PG  Action  1980  June 19, 1981 (United States)    6.8
#
#     votes        director        writer          star        country  \
# 8  101000  Richard Lester  Jerry Siegel  Gene Hackman  United States
#
#      budget        gross         company runtime,,
# 8  54000000  108185706.0  Dovemead Films    127.0,

# %%
df.groupby(['name','rating']).get_group(('Superman II','PG'))
# Out:
#           name rating   genre  year                       released  score  \
# 8  Superman II     PG  Action  1980  June 19, 1981 (United States)    6.8
#
#     votes        director        writer          star        country  \
# 8  101000  Richard Lester  Jerry Siegel  Gene Hackman  United States
#
#      budget        gross         company runtime,,
# 8  54000000  108185706.0  Dovemead Films    127.0,

# %% [markdown]
# make a group of the data where rating is pg and gener is action

# %%
df.groupby(['rating','genre']).get_group(('R','Biography'))
# Out:
#                         name rating      genre  year  \
# 7                Raging Bull      R  Biography  1980
# 9            The Long Riders      R  Biography  1980
# 43    Where the Buffalo Roam      R  Biography  1980
# 132           Mommie Dearest      R  Biography  1981
# 261                  Frances      R  Biography  1982
# ...                      ...    ...        ...   ...
# 3770      Before Night Falls      R  Biography  2000
# 3866                    Blow      R  Biography  2001
# 3942                     Ali      R  Biography  2001
# 3984                    Iris      R  Biography  2001
# 3985       Nowhere in Africa      R  Biography  2001
#
#                                 released  score   votes         director  \
# 7      December 19, 1980 (United States)    8.2  330000  Martin Scorsese
# 9           May 16, 1980 (United States)    7.0   10000      Walter Hill
# 43        April 25, 1980 (United States)    6.6   11000       Art Linson
# ...

# %%
df.groupby(['rating','genre']).get_group(('R','Crime'))

# %%
df.groupby(['rating','genre']).get_group(('R','Crime'))

# %% [markdown]
# # Gropuing by using the loc

# %%
df.loc[df.genre=="Crime"]  # !=  not equal to
# Out:
#                           name rating  genre  year  \
# 14             Dressed to Kill      R  Crime  1980
# 20                    Cruising      R  Crime  1980
# 28                    Brubaker      R  Crime  1980
# 29             American Gigolo      R  Crime  1980
# 93                   Body Heat      R  Crime  1981
# ...                        ...    ...    ...   ...
# 3921                The Pledge      R  Crime  2001
# 3924  The Man Who Wasn't There      R  Crime  2001
# 3929           The Glass House  PG-13  Crime  2001
# 3935                  Baby Boy      R  Crime  2001
# 3948            In the Bedroom      R  Crime  2001
#
#                                 released  score   votes          director  \
# 14         July 25, 1980 (United States)    7.1   37000    Brian De Palma
# 20     February 15, 1980 (United States)    6.5   20000  William Friedkin
# 28         June 20, 1980 (United States)    7.2   17000  Stuart Rosenberg
# ...

# %%
df.loc[df.genre == 'Crime']

# %%
df.loc[df['genre'] == 'Crime']

# %%
df.loc[(df.genre == 'Crime')&(df.rating == 'R')]  # gener = crime and rating R

# %%
df.loc[(df.genre == 'Crime')|(df.rating == 'R')]

# %%
df.loc[(df.genre == 'Crime')&((df.rating == 'R')|(df.rating == 'PG'))]

# %%
df.loc[(df.budget <= 100000)]

# %%
df.loc[(df. budget >=6500000 )&(df.budget <=11000000)]

# %%
df.loc[(df.score >6.4 )]

# %% [markdown]
# ## insert

# %% [markdown]
# df.insert(location_index, column_name , column_values)

# %%
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,3,4,5], 'B':[10,20,30,40,50]})
df

# %%
df.insert(2, 'C', [1,2,3,4,5])
df

# %%
df.insert(1,'d',"python")
df

# %%
data = {"name":["Niraman","Abhishek","Gaytri"],"Location":["Pune","Nashik","Junnar"]}
data

# %%
df_1 = pd.DataFrame(data)
df_1

# %%
df.insert(location_index, column_name , column_values)

# %%
df_1.insert(0,"CGPA",[9.4,9.2,9.2])
df_1

# %% [markdown]
# ## Rename

# %%
df_1

# %%
df_1.rename({'name':'Name'},axis=1)   #axis 1 = columns

# %%
df_1.rename({'name':'Name'},axis=0)

# %%
df_1.T.rename({"name":"Name"},axis = 0)

# %%
df_1
